# %%
from numpy import random
x=random.randint(100)
print(x)
# Out:
# 10

# %%
from numpy import random
x=random.rand(100)
print(x)
# Out:
# [0.20023778 0.03673629 0.10261698 0.38800923 0.07811144 0.55065677
#  0.7345393  0.168292   0.06179138 0.42079042 0.58610523 0.45304486
#  0.83095207 0.85623738 0.81350839 0.29065059 0.35673792 0.43690144
#  0.86844518 0.12697546 0.22177368 0.35811558 0.89913375 0.27812709
#  0.94741941 0.96045847 0.82908148 0.32481085 0.72066396 0.91761841
#  0.42593155 0.20277143 0.56022095 0.96012236 0.03564948 0.1601086
#  0.57783654 0.87759201 0.46058683 0.12425453 0.45993167 0.9981329
#  0.24546312 0.80141086 0.41497076 0.20281679 0.92166209 0.87623051
#  0.19686276 0.4056295  0.52916179 0.32445452 0.71896146 0.01315701
#  0.12926704 0.91415685 0.73750404 0.02584899 0.22263922 0.48822516
#  0.51443182 0.31409017 0.30966472 0.6850497  0.33121293 0.96624678
#  0.1916776  0.14937633 0.82837729 0.25544069 0.2238395  0.45028557
#  0.13960022 0.40312237 0.71257268 0.38981602 0.04027225 0.65755344
#  0.52067759 0.71164325 0.17570565 0.44182218 0.61755861 0.6770498
#  0.42703498 0.84321335 0.78249419 0.91903997 0.17814777 0.56316873
#  0.19563075 0.48201185 0.37382892 0.3775229  0.92901643 0.87165155
#  0.17101831 0.83160408 0.75477487 0.48966   ]

# %%
from numpy import random
x=random.choice([3,5,7,9],p=[0.1,0.3,0.6,0.0],size=(10))
print(x)
# Out:
# [5 5 5 7 7 7 7 5 7 3]

# %%
from numpy import random
x=random.choice([3,5,7,9], p=[0.1,0.3,0.6,0.0],size=(3,5))
print(x)
# Out:
# [[5 7 5 7 5]
#  [7 5 3 3 5]
#  [7 7 5 5 7]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=1000),hist=True)
plt.show()
# Out:
# C:\Users\aryan\AppData\Local\Temp\ipykernel_5576\1169273569.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist=True)

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=1000),hist=False)
plt.show()
# Out:
# C:\Users\aryan\AppData\Local\Temp\ipykernel_5576\799546936.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist=False)

# %%
from numpy import random
x=random.binomial(n=100,p=0.5,size=100)
print(x)
# Out:
# [49 49 53 38 48 49 44 56 44 49 50 52 51 47 52 56 53 55 45 46 56 42 58 50
#  42 50 47 50 46 49 45 43 48 40 55 52 44 47 55 56 50 47 47 62 50 44 45 45
#  51 46 45 49 45 49 46 55 50 48 49 47 53 52 47 42 51 49 49 56 45 56 47 51
#  53 51 46 54 58 54 51 53 47 47 48 48 39 51 45 50 45 48 51 51 52 51 48 45
#  51 49 50 50]

# %%
from numpy import random
x=random.chisquare(df=2,size=(2,3))
print(x)
# Out:
# [[3.91683165 1.55239724 4.653591  ]
#  [1.5154848  2.01952235 0.49672859]]
